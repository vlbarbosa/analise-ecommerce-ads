# %%
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns

print("Bibliotecas importadas com sucesso! O ambiente está pronto.")
# Out:
# Bibliotecas importadas com sucesso! O ambiente está pronto.

# %%
# Definindo onde estão os nossos arquivos
# Certifique-se de que os arquivos baixados do Kaggle estão dentro da pasta 'data'
caminho_pedidos = 'data/olist_orders_dataset.csv'
caminho_itens = 'data/olist_order_items_dataset.csv'

try:
    # O comando pd.read_csv lê o arquivo e o transforma em um DataFrame
    df_pedidos = pd.read_csv(caminho_pedidos)
    df_itens = pd.read_csv(caminho_itens)
    
    print("✅ Dados carregados com sucesso para a memória!")
    
    # .head() é como dar uma "espiadinha" nas 5 primeiras linhas para ver se está tudo certo
    display(df_pedidos.head())
    
except FileNotFoundError:
    print("⚠️ Opa! O Python não achou os arquivos.")
    print("Verifique se você criou a pasta 'data' e colocou os arquivos CSV do Olist lá dentro com esses nomes exatos.")
# Out:
# ⚠️ Opa! O Python não achou os arquivos.
# Verifique se você criou a pasta 'data' e colocou os arquivos CSV do Olist lá dentro com esses nomes exatos.
